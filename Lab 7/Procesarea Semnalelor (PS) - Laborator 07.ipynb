# %% [markdown]
# # Pachete necesare pentru folosirea acestui Notebook
#
# Vom folosi [scipy](https://scipy.org/), [numpy](https://numpy.org/) și [matplotlib](https://matplotlib.org/).

# %%
from scipy import misc, ndimage
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2 as cv
# Out:
# C:\Users\mihai\AppData\Local\Temp\ipykernel_30888\2317938629.py:1: DeprecationWarning: scipy.misc is deprecated and will be removed in 2.0.0
#   from scipy import misc, ndimage

# %% [markdown]
# # Imaginea cu care lucrăm
#
# Vom folosi o imagine din setul de date oferit implicit de către scipy.

# %%
img = Image.open('raton.png').convert('L').resize((1024, 768))
X = np.array(img)
plt.imshow(X, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# # Transformata Fourier a unei imagini
#
# Transformata Fourier Discretă se extinde ușor la mai multe dimensiuni. Pentru un semnal bidimensional precum o imagine DFT devine:
#
# $$
# Y_{m_1,m_2} = \sum_{n_1=0}^{N_1-1}\sum_{n_2=0}^{N_2-1}x_{n_1,n_2}e^{-j2\pi(m_1 n_1/N_1 + m_2 n_2/N_2)}
# $$
#
# * unde $n_1$ și $n_2$ sunt pozițile pixelilor pe orizontală, respectiv, pe verticală
# * bin-urile rezultate corespund pozițiilor pixelilor
# * spectrul este în continuare simetric
# * proprietățile transformatei DFT 1D sunt respectate și în cazul celei 2D
#
# În continuare vom folosi rutina generală `fft2` ce servește mai bine activității de învățare, deși pentru semnale reale ar trebui să folosim `rfft2` ce întoarce doar informația esențială (ex. omite simetriile). De asemenea vom analiza spectrul în scală logaritmică pentru a diferenția mai bine magnitudinile bin-urilor DTF.

# %%
Y = np.fft.fft2(X)
freq_db = 20*np.log10(abs(Y))

plt.imshow(freq_db)
plt.colorbar()
plt.show()

# %% [markdown]
# Operațiile efectuate direct asupra imaginii se reflectă și în spectrul acesteia. Iată un exemplu a unei rotații de 45 de grade:

# %%
rotate_angle = 45
X45 = ndimage.rotate(X, rotate_angle)
plt.imshow(X45, cmap=plt.cm.gray)
plt.show()

Y45 = np.fft.fft2(X45)
plt.imshow(20*np.log10(abs(Y45)))
plt.colorbar()
plt.show()

# %% [markdown]
# Momentan pe axe sunt afișate numărul bin-urilor. Pentru a obține frecvențele asociate folosiți `fftfreq`:

# %%
freq_x = np.fft.fftfreq(X.shape[1])
freq_y = np.fft.fftfreq(X.shape[0])

plt.stem(freq_x, freq_db[:][0])
plt.show()

# %% [markdown]
# # Atenuarea frecvențelor înalte
#
# Pentru a anula frecvențele de peste un anumit prag `freq_cutoff` putem pur și simplu anula intrările din spectru și aplica transformata Fourier inversă:

# %%
freq_cutoff = 120

Y_cutoff = Y.copy()
Y_cutoff[freq_db > freq_cutoff] = 0
X_cutoff = np.fft.ifft2(Y_cutoff)
X_cutoff = np.real(X_cutoff)    # avoid rounding erros in the complex domain,
                                # in practice use irfft2
plt.imshow(X_cutoff, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# # Zgomot
#
# Zgomotul alb perturbă în mod egal spectrul semnalului. Este astfel egal distribuit și regăsit în toate bin-urile DFT. [Zgomotul color](https://en.wikipedia.org/wiki/Colors_of_noise) se schimbă de-a lungul frecvențelor.
#
# Putem adăuga zgomot în limita a `pixel_noise` pixeli imaginii folosind `random.randint`:

# %%
pixel_noise = 200

noise = np.random.randint(-pixel_noise, high=pixel_noise+1, size=X.shape)
X_noisy = X + noise
plt.imshow(X, cmap=plt.cm.gray)
plt.title('Original')
plt.show()
plt.imshow(X_noisy, cmap=plt.cm.gray)
plt.title('Noisy')
plt.show()

# %% [markdown]
# # Sarcini
#
# 1. Produceți imaginile și spectrul pentru funcțiile de mai jos și dați o explicație scurtă pentru fiecare rezultat.
# * $x_{n_1,n_2} = \sin(2\pi n_1 + 3\pi n_2)$
# * $x_{n_1,n_2} = \sin(4\pi n_1) + \cos(6\pi n_2)$
# * $Y_{0,5} = Y_{0,N-5} = 1\text{, altfel }Y_{m_1,m_2} = 0,\ \forall m_1, m_2$
# * $Y_{5,0} = Y_{N-5,0} = 1\text{, altfel }Y_{m_1,m_2} = 0,\ \forall m_1, m_2$
# * $Y_{5,5} = Y_{N-5,N-5} = 1\text{, altfel }Y_{m_1,m_2} = 0,\ \forall m_1, m_2$
#
# *Atenție*: $x$ reprezintă informație în domeniul timpului, $Y$ în domeninul frecvenței.
#
# 2. Comprimați imaginea cu ratonul de mai sus prin atenuarea frecvențelor înalte până la un prag SNR autoimpus.
#
# 3. Eliminați zgomotul adăugat la imaginea cu ratonul produsă mai sus. Prezentați raportul SNR înainte și după.

# %% [markdown]
# # EXERCITIUL 1

# %%
sz = 64

f = np.zeros((sz, sz))
for i in range(sz):
    for j in range(sz):
        f[i, j] = np.sin(2*np.pi*i + 3*np.pi*j)
plt.title("sin(2pi*n1+3pi*n2)")
plt.imshow(f)
plt.show()

f2 = np.zeros((sz, sz))
for i in range(sz):
    for j in range(sz):
        f2[i, j] = np.sin(4*np.pi*i) + np.cos(6*np.pi*j)
plt.title("sin(4pi*n1) + cos(6pi*n2)") # oscilatia creste odata cu x1 si x2
plt.imshow(f2)
plt.show()

F3 = np.zeros((sz, sz))
F3[0, 5] = F3[0, sz-5] = 1
f3 = np.abs(np.fft.ifft2(F3))
plt.title("frecventa (0, 5)") # vertical deoarece avem doar frecventa 5 (cu alte cuvinte o sinusoida)
plt.imshow(f3)
plt.show()

F4 = np.zeros((sz, sz))
F4[5, 0] = F4[sz-5, 0] = 1
f4 = np.abs(np.fft.ifft2(F4))
plt.title("frecventa (5, 0)") # ca la ex anterior dar pe orizontala
plt.imshow(f4)
plt.show()

F5 = np.zeros((sz, sz))
F5[5, 5] = F5[sz-5, sz-5] = 1
f5 = np.abs(np.fft.ifft2(F5))
plt.title("frecventa (5, 5)") # ca la ex anterioare dar pe diagonala
plt.imshow(f5)
plt.show()

# %% [markdown]
# # EXERCITIUL 2

# %%
def snr(original, with_noise):
    s_power = np.sum(original ** 2)
    n_power = np.sum((original - with_noise) ** 2)
    return np.real(10 * np.log10(s_power / n_power))

def compress(original, snr_thresh):
    sz = original.shape
    four = np.fft.fft2(original)
    four_flat = four.flatten()
    order = np.argsort(abs(four_flat))
    
    i = 0
    while True:
        for repeat in range(2500):
            four[order[i] // sz[1], order[i] % sz[1]] = 0
            i += 1
        new_X = np.fft.ifft2(four)
        
        s = snr(original, new_X)
        print(s)
        if s < snr_thresh:
            return np.abs(new_X)

noisy_racoon = compress(X, 5)
plt.imshow(noisy_racoon)
plt.title("Removed high frequencies")
plt.show()
# Out:
# 70.0306144026578
# 63.94050232447902
# 60.40737993415901
# 57.89527331824689
# 55.93584621405215
# 54.32855949113516
# 52.96223547189775
# 51.77079711325661
# 50.71638795807044
# 49.76657580115136
# 48.90195626281515
# 48.109172019754624
# 47.37597235072366
# 46.693332314110386
# 46.053829234293374
# 45.45222832549581
# 44.883667680138835
# 44.34459609412463
# 43.83125274932261
# 43.34064035230878
# 42.870584325333034
# 42.41837255325348
# 41.98226904552391
# 41.561796470156416
# 41.15511445156347
# 40.761073228205156
# 40.378522484708284
# 40.00656242574056
# 39.64415164645486
# 39.290706007309446
# 38.94473696705033
# 38.605487647456286
# 38.272745603082214
# 37.945993224144466
# 37.62446282823278
# 37.30720692559313
# 36.993677748372214
# 36.68342726532451
# 36.37524919748165
# 36.06870121177388
# 35.763162930084754
# 35.45815712670283
# 35.15312076281586
# 34.8464493583323
# 34.53707231962098
# 34.22354658638377
# 33.90431338503486
# 33.578268609956275
# 33.2433667064469
# 32.89740416344238
# 32.537878968366385
# 32.16186693206
# 31.76604024637286
# 31.347362300949552
# 30.902810806662572
# 30.430450002124807
# 29.92763153974337
# 29.39246013458636
# 28.823608472767795
# 28.220268316499247
# 27.58016271513665
# 26.89703456794537
# 26.16477640234971
# 25.38305342413892
# 24.55690148938467
# 23.685191203664427
# 22.753249589351732
# 21.743310343271194
# 20.659313697205462
# 19.526139441540014
# 18.34646435917332
# 17.076761311681842
# 15.723739241038391
# 14.202476433268869
# 12.36200554550299
# 10.066958349554865
# 6.86468732520313
# 1.8695819630855453

# %% [markdown]
# # EXERCITIUL 3

# %%
denoised = cv.GaussianBlur(noisy_racoon, (0, 0), 1)
print(snr(X, denoised))
plt.imshow(denoised)
plt.title("denoised")
plt.show()
# Out:
# 1.9311293815629673
